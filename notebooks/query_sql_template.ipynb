# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the Congressional Data database. In order to use this notebook, you will need to set an environment variable 'CD_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-congressdata channel and/or talk to a project lead.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os
import sys

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

DB_URI = os.getenv('CD_DWH')
engine = create_engine(DB_URI)

# %%
# Checking that the Kernel is using the Conda environment datasci-congressional-data
# Below you should see something like '/Users/Username/anaconda3/envs/datasci-congressional-data/bin/python
# If you do NOT see "datasci-congressional-data" this means you are not in the right Python Environment
# Please make sure you have gone through the onboarding docs and/or talk to a project lead.
sys.executable
# Out:
# '/home/vla/anaconda3/bin/python'

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#               table_catalog   table_schema  \
# 0  datascicongressionaldata    data_ingest
# 1  datascicongressionaldata    data_ingest
# 2  datascicongressionaldata  stg_analytics
# 3  datascicongressionaldata    data_ingest
# 4  datascicongressionaldata    data_ingest
# 5  datascicongressionaldata    data_ingest
# 6  datascicongressionaldata  trg_analytics
# 7  datascicongressionaldata  stg_analytics
#
#                                           table_name  table_type  \
# 0  casos__california_candidate_statewide_election...  BASE TABLE
# 1  ceda__california_candidate_local_election_results  BASE TABLE
# 2                        stg_candidate_contributions  BASE TABLE
# 3         sfdata__campaign_finance_form460_schedulea  BASE TABLE
# 4                     maplight__california_candidate  BASE TABLE
# 5                         maplight__california_other  BASE TABLE
# 6                            candidate_contributions  BASE TABLE
# 7                     stg_candidate_election_results  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None

# %% [markdown]
# ## Query Example

# %%
QUERY = """
select
  *
from trg_analytics.candidate_contributions
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#      transaction_id       transaction_type election_cycle    election  \
# 0   2176430 - INC21  Monetary Contribution           2017  2018-06-05
# 1  2176430 - INC102  Monetary Contribution           2017  2018-06-05
# 2  2176430 - INC169  Monetary Contribution           2017  2018-06-05
# 3  2176430 - INC137  Monetary Contribution           2017  2018-06-05
# 4   2176430 - INC54  Monetary Contribution           2017  2018-06-05
# 5    2176430 - INC7  Monetary Contribution           2017  2018-06-05
# 6  2176430 - INC105  Monetary Contribution           2017  2018-06-05
# 7   2176430 - INC79  Monetary Contribution           2017  2018-06-05
# 8  2176430 - INC133  Monetary Contribution           2017  2018-06-05
# 9   2176430 - INC82  Monetary Contribution           2017  2018-06-05
#
#    primary_general_indicator transaction_date  transaction_amount  filed_date  \
# 0                          0       2017-02-08              1000.0  2017-07-31
# 1                          0       2017-05-19              1000.0  2017-07-31
# 2                          0       2017-06-27              1000.0  2017-07-31
# 3                          0       2017-06-12              1000.0  2017-07-31
# 4                          0       2017-03-23              3000.0  2017-07-31
# 5                          0       2017-01-27              1000.0  2017-07-31
# 6                          0       2017-05-19              1000.0  2017-07-31
# 7                          0       2017-04-28              4400.0  2017-07-31
# 8                          0       2017-06-05              1000.0  2017-07-31
# 9                          0       2017-05-02              1000.0  2017-07-31
#
#                 recipient_committee_name recipient_candidate_name  \
# 0  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 1  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 2  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 3  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 4  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 5  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 6  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 7  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 8  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
# 9  Re-Elect Ken Cooley for Assembly 2018              COOLEY, KEN
#
#   recipient_candidate_party recipient_candidate_ico  \
# 0   NOT CURRENTLY SUPPORTED                    None
# 1   NOT CURRENTLY SUPPORTED                    None
# 2   NOT CURRENTLY SUPPORTED                    None
# 3   NOT CURRENTLY SUPPORTED                    None
# 4   NOT CURRENTLY SUPPORTED                    None
# 5   NOT CURRENTLY SUPPORTED                    None
# 6   NOT CURRENTLY SUPPORTED                    None
# 7   NOT CURRENTLY SUPPORTED                    None
# 8   NOT CURRENTLY SUPPORTED                    None
# 9   NOT CURRENTLY SUPPORTED                    None
#
#   recipient_candidate_status recipient_candidate_office  \
# 0    NOT CURRENTLY SUPPORTED             State Assembly
# 1    NOT CURRENTLY SUPPORTED             State Assembly
# 2    NOT CURRENTLY SUPPORTED             State Assembly
# 3    NOT CURRENTLY SUPPORTED             State Assembly
# 4    NOT CURRENTLY SUPPORTED             State Assembly
# 5    NOT CURRENTLY SUPPORTED             State Assembly
# 6    NOT CURRENTLY SUPPORTED             State Assembly
# 7    NOT CURRENTLY SUPPORTED             State Assembly
# 8    NOT CURRENTLY SUPPORTED             State Assembly
# 9    NOT CURRENTLY SUPPORTED             State Assembly
#
#   recipient_candidate_district  \
# 0                          8.0
# 1                          8.0
# 2                          8.0
# 3                          8.0
# 4                          8.0
# 5                          8.0
# 6                          8.0
# 7                          8.0
# 8                          8.0
# 9                          8.0
#
#                                           donor_name     donor_city  \
# 0  Professional Engineers in California Governmen...     Sacramento
# 1  Professional Engineers in California Governmen...     Sacramento
# 2  Ricon Band of Luiseno Mission Indians of the R...  Valley Center
# 3                  Sentry Insurance A Mutual Company  Stevens Point
# 4            Southern Glazer's Wine and Spirits, LLC        Miramar
# 5  State Building and Construction Trades Council...     Sacramento
# 6                             Tesoro Companies, Inc.       Martinez
# 7                            The Doctors Company PAC           Napa
# 8                        The Hartford Advocates Fund       Hartford
# 9  The Political Action Committee of the American...     Alexandria
#
#   donor_state donor_zip_code donor_employer         donor_occupation  \
# 0          CA          95814           None  NOT CURRENTLY SUPPORTED
# 1          CA          95814           None  NOT CURRENTLY SUPPORTED
# 2          CA          92082           None  NOT CURRENTLY SUPPORTED
# 3          WI          54481           None  NOT CURRENTLY SUPPORTED
# 4          FL          33027           None  NOT CURRENTLY SUPPORTED
# 5          CA          95814           None  NOT CURRENTLY SUPPORTED
# 6          CA          94553           None  NOT CURRENTLY SUPPORTED
# 7          CA          94558           None  NOT CURRENTLY SUPPORTED
# 8          CT          06115           None  NOT CURRENTLY SUPPORTED
# 9          CA          22314           None  NOT CURRENTLY SUPPORTED
#
#   donor_organization donor_industry        donor_entity_type  \
# 0                COM         822501  NOT CURRENTLY SUPPORTED
# 1                COM         822501  NOT CURRENTLY SUPPORTED
# 2                OTH              0  NOT CURRENTLY SUPPORTED
# 3                OTH              0  NOT CURRENTLY SUPPORTED
# 4                OTH              0  NOT CURRENTLY SUPPORTED
# 5                COM         743501  NOT CURRENTLY SUPPORTED
# 6                OTH              0  NOT CURRENTLY SUPPORTED
# 7                COM         923140  NOT CURRENTLY SUPPORTED
# 8                OTH              0  NOT CURRENTLY SUPPORTED
# 9                OTH         742617  NOT CURRENTLY SUPPORTED
#
#         donor_committee_id     donor_committee_name donor_committee_type  \
# 0  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 1  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 2  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 3  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 4  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 5  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 6  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 7  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 8  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 9  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
#
#   donor_committee_party
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
