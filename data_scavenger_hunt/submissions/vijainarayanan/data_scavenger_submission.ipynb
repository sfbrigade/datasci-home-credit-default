# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the Congressional Data database. In order to use this notebook, you will need to set an environment variable 'CD_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-congressdata channel and/or talk to a project lead.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os
import sys

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

DB_URI = os.getenv('CD_DWH')
engine = create_engine(DB_URI)

# %%
# Checking that the Kernel is using the Conda environment datasci-congressional-data
# Below you should see something like '/Users/Username/anaconda3/envs/datasci-congressional-data/bin/python
# If you do NOT see "datasci-congressional-data" this means you are not in the right Python Environment
# Please make sure you have gone through the onboarding docs and/or talk to a project lead.
sys.executable
# Out:
# '/anaconda/envs/congressdata/bin/python'

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#               table_catalog   table_schema  \
# 0  datascicongressionaldata  stg_analytics
# 1  datascicongressionaldata  stg_analytics
# 2  datascicongressionaldata    data_ingest
# 3  datascicongressionaldata  trg_analytics
# 4  datascicongressionaldata    data_ingest
# 5  datascicongressionaldata    data_ingest
# 6  datascicongressionaldata    data_ingest
# 7  datascicongressionaldata    data_ingest
#
#                                           table_name  table_type  \
# 0                        stg_candidate_contributions  BASE TABLE
# 1                     stg_candidate_election_results  BASE TABLE
# 2         sfdata__campaign_finance_form460_schedulea  BASE TABLE
# 3                            candidate_contributions  BASE TABLE
# 4                     maplight__california_candidate  BASE TABLE
# 5                         maplight__california_other  BASE TABLE
# 6  casos__california_candidate_statewide_election...  BASE TABLE
# 7  ceda__california_candidate_local_election_results  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None

# %% [markdown]
# ## Query Example

# %%
# %%time
QUERY = """
select
  *
from trg_analytics.candidate_contributions
"""
# removed limit 1000 from query (I want to pull all the rows in the table, not just 1000)
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
# Out:
# CPU times: user 28.7 s, sys: 15.9 s, total: 44.5 s
# Wall time: 4min 34s

# %%
results.head(100)
# Out:
#       transaction_id       transaction_type election_cycle    election  \
014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 1   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 2   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 3   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 4   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 5   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 6   2014-05-22           Betsy Butler for Assembly 2014
# 7   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 8   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 9   2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 10  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 11  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 12  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 13  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 14  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 15  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 16  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 17  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 18  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 19  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 20  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 21  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 22  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 23  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 24  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 25  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 26  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 27  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 28  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 29  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# ..         ...                                      ...
# 70  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 71  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 72  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 73  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 74  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 75  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 76  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 77  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 78  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 79  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 80  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 81  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 82  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 83  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 84  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 85  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 86  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 87  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 88  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 89  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 90  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 91  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 92  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 93  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 94  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 95  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 96  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 97  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 98  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
# 99  2014-01-31  Taxpayers for Jim Nielsen - Senate 2014
#
#    recipient_candidate_name recipient_candidate_party recipient_candidate_ico  \
# 0              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 1              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 2              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 3              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 4              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 5              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 6             BUTLER, BETSY   NOT CURRENTLY SUPPORTED                    None
# 7              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 8              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 9              NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 10             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 11             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 12             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 13             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 14             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 15             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 16             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 17             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 18             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 19             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 20             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 21             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 22             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 23             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 24             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 25             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 26             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 27             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 28             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 29             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# ..                      ...                       ...                     ...
# 70             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 71             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 72             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 73             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 74             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 75             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 76             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 77             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 78             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 79             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 80             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 81             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 82             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 83             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 84             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 85             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 86             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 87             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 88             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 89             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 90             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 91             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 92             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 93             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 94             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 95             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 96             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 97             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 98             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
# 99             NIELSEN, JIM   NOT CURRENTLY SUPPORTED                    None
#
#    recipient_candidate_status recipient_candidate_office  \
# 0     NOT CURRENTLY SUPPORTED               State Senate
# 1     NOT CURRENTLY SUPPORTED               State Senate
# 2     NOT CURRENTLY SUPPORTED               State Senate
# 3     NOT CURRENTLY SUPPORTED               State Senate
# 4     NOT CURRENTLY SUPPORTED               State Senate
# 5     NOT CURRENTLY SUPPORTED               State Senate
# 6     NOT CURRENTLY SUPPORTED             State Assembly
# 7     NOT CURRENTLY SUPPORTED               State Senate
# 8     NOT CURRENTLY SUPPORTED               State Senate
# 9     NOT CURRENTLY SUPPORTED               State Senate
# 10    NOT CURRENTLY SUPPORTED               State Senate
# 11    NOT CURRENTLY SUPPORTED               State Senate
# 12    NOT CURRENTLY SUPPORTED               State Senate
# 13    NOT CURRENTLY SUPPORTED               State Senate
# 14    NOT CURRENTLY SUPPORTED               State Senate
# 15    NOT CURRENTLY SUPPORTED               State Senate
# 16    NOT CURRENTLY SUPPORTED               State Senate
# 17    NOT CURRENTLY SUPPORTED               State Senate
# 18    NOT CURRENTLY SUPPORTED               State Senate
# 19    NOT CURRENTLY SUPPORTED               State Senate
# 20    NOT CURRENTLY SUPPORTED               State Senate
# 21    NOT CURRENTLY SUPPORTED               State Senate
# 22    NOT CURRENTLY SUPPORTED               State Senate
# 23    NOT CURRENTLY SUPPORTED               State Senate
# 24    NOT CURRENTLY SUPPORTED               State Senate
# 25    NOT CURRENTLY SUPPORTED               State Senate
# 26    NOT CURRENTLY SUPPORTED               State Senate
# 27    NOT CURRENTLY SUPPORTED               State Senate
# 28    NOT CURRENTLY SUPPORTED               State Senate
# 29    NOT CURRENTLY SUPPORTED               State Senate
# ..                        ...                        ...
# 70    NOT CURRENTLY SUPPORTED               State Senate
# 71    NOT CURRENTLY SUPPORTED               State Senate
# 72    NOT CURRENTLY SUPPORTED               State Senate
# 73    NOT CURRENTLY SUPPORTED               State Senate
# 74    NOT CURRENTLY SUPPORTED               State Senate
# 75    NOT CURRENTLY SUPPORTED               State Senate
# 76    NOT CURRENTLY SUPPORTED               State Senate
# 77    NOT CURRENTLY SUPPORTED               State Senate
# 78    NOT CURRENTLY SUPPORTED               State Senate
# 79    NOT CURRENTLY SUPPORTED               State Senate
# 80    NOT CURRENTLY SUPPORTED               State Senate
# 81    NOT CURRENTLY SUPPORTED               State Senate
# 82    NOT CURRENTLY SUPPORTED               State Senate
# 83    NOT CURRENTLY SUPPORTED               State Senate
# 84    NOT CURRENTLY SUPPORTED               State Senate
# 85    NOT CURRENTLY SUPPORTED               State Senate
# 86    NOT CURRENTLY SUPPORTED               State Senate
# 87    NOT CURRENTLY SUPPORTED               State Senate
# 88    NOT CURRENTLY SUPPORTED               State Senate
# 89    NOT CURRENTLY SUPPORTED               State Senate
# 90    NOT CURRENTLY SUPPORTED               State Senate
# 91    NOT CURRENTLY SUPPORTED               State Senate
# 92    NOT CURRENTLY SUPPORTED               State Senate
# 93    NOT CURRENTLY SUPPORTED               State Senate
# 94    NOT CURRENTLY SUPPORTED               State Senate
# 95    NOT CURRENTLY SUPPORTED               State Senate
# 96    NOT CURRENTLY SUPPORTED               State Senate
# 97    NOT CURRENTLY SUPPORTED               State Senate
# 98    NOT CURRENTLY SUPPORTED               State Senate
# 99    NOT CURRENTLY SUPPORTED               State Senate
#
#    recipient_candidate_district  \
# 0                           4.0
# 1                           4.0
# 2                           4.0
# 3                           4.0
# 4                           4.0
# 5                           4.0
# 6                          62.0
# 7                           4.0
# 8                           4.0
# 9                           4.0
# 10                          4.0
# 11                          4.0
# 12                          4.0
# 13                          4.0
# 14                          4.0
# 15                          4.0
# 16                          4.0
# 17                          4.0
# 18                          4.0
# 19                          4.0
# 20                          4.0
# 21                          4.0
# 22                          4.0
# 23                          4.0
# 24                          4.0
# 25                          4.0
# 26                          4.0
# 27                          4.0
# 28                          4.0
# 29                          4.0
# ..                          ...
# 70                          4.0
# 71                          4.0
# 72                          4.0
# 73                          4.0
# 74                          4.0
# 75                          4.0
# 76                          4.0
# 77                          4.0
# 78                          4.0
# 79                          4.0
# 80                          4.0
# 81                          4.0
# 82                          4.0
# 83                          4.0
# 84                          4.0
# 85                          4.0
# 86                          4.0
# 87                          4.0
# 88                          4.0
# 89                          4.0
# 90                          4.0
# 91                          4.0
# 92                          4.0
# 93                          4.0
# 94                          4.0
# 95                          4.0
# 96                          4.0
# 97                          4.0
# 98                          4.0
# 99                          4.0
#
#                                            donor_name       donor_city  \
# 4           CA          95608                                None
# 5           CA          90020                                None
# 6           CA          90278                                None
# 7           CA          90020                                None
# 8           CA          91521                                None
# 9           CA          95955                                None
# 10          CA          94534                    B & L Properties
# 11          CA          94534                    B & L Properties
# 12          CA          94534                                None
# 13          CA          94534                                None
# 14          CA          95608                                None
# 15          CA          95987                                None
# 16          CA          95970                        Hansen Farms
# 17          CA          95630                                None
# 18          CA          94301                                None
# 19          CA          95674                Norene Ranches, Inc.
# 20          CA          95814                                None
# 21          CA          94533           Jelly Belly Candy Company
# 22          CA          92882                                None
# 23          CA          94941                                None
# 24          CA          94105                                None
# 25          CA          94558                                None
# 26          CA          95987                                None
# 27          WI          53705                                None
# 28          KS          67215                                None
# 29          CA          95991                                None
# ..         ...            ...                                 ...
# 70          CA          90071                                None
# 71          CA          96080                       Edwards Ranch
# 72          CA          95746                                None
# 73          CA          95963                   Animal Blood Bank
# 74          CA          95993                                None
# 75          CA          95692                Norene Ranches, Inc.
# 76          CA          95991                                None
# 77          CA          95973                                None
# 78          CA          95926                  L & A Tennis Farms
# 79          CA          95948            Stuker Nursery Co., Inc.
# 80          CA          96092              Matt Anchordoguy & Co.
# 81          CA          95938                                None
# 82          CA          95814                                None
# 83          CA          95973                                None
# 84          CA          95928                     M&T Chico Ranch
# 85          CA          95938                         Farm Credit
# 86          CA          95926               Lundberg Family Farms
# 87          CA          95943                McCorkle Farms, Inc.
# 88          CA          96080                                None
# 89          CA          96080                                None
# 90          CA          95926  California State University, Chico
# 91          CA          90024                                None
# 92          CA          92592                                None
# 93          NJ          08807                                None
# 94          CA          95814                                None
# 95          CA          95966                                None
# 96          CA          95966                                None
# 97          CA          95674                                None
# 98          CA          95687                       Yin McDonalds
# 99          CA          95932                                None
#
#            donor_occupation donor_organization donor_industry  \
# 0   NOT CURRENTLY SUPPORTED                IND              0
# 1   NOT CURRENTLY SUPPORTED                OTH              0
# 2   NOT CURRENTLY SUPPORTED                OTH              0
# 3   NOT CURRENTLY SUPPORTED                IND              0
# 4   NOT CURRENTLY SUPPORTED                OTH              0
# 5   NOT CURRENTLY SUPPORTED                COM         890106
# 6   NOT CURRENTLY SUPPORTED                IND              0
# 7   NOT CURRENTLY SUPPORTED                COM         890106
# 8   NOT CURRENTLY SUPPORTED                OTH              0
# 9   NOT CURRENTLY SUPPORTED                OTH              0
# 10  NOT CURRENTLY SUPPORTED                IND              0
# 11  NOT CURRENTLY SUPPORTED                IND              0
# 12  NOT CURRENTLY SUPPORTED                IND              0
# 13  NOT CURRENTLY SUPPORTED                IND              0
# 14  NOT CURRENTLY SUPPORTED                IND              0
# 15  NOT CURRENTLY SUPPORTED                OTH              0
# 16  NOT CURRENTLY SUPPORTED                IND              0
# 17  NOT CURRENTLY SUPPORTED                OTH              0
# 18  NOT CURRENTLY SUPPORTED                IND              0
# 19  NOT CURRENTLY SUPPORTED                IND              0
# 20  NOT CURRENTLY SUPPORTED                COM         921655
# 21  NOT CURRENTLY SUPPORTED                IND              0
# 22  NOT CURRENTLY SUPPORTED                OTH              0
# 23  NOT CURRENTLY SUPPORTED                COM         901422
# 24  NOT CURRENTLY SUPPORTED                OTH              0
# 25  NOT CURRENTLY SUPPORTED                COM         923140
# 26  NOT CURRENTLY SUPPORTED                OTH              0
# 27  NOT CURRENTLY SUPPORTED                OTH              0
# 28  NOT CURRENTLY SUPPORTED                OTH              0
# 29  NOT CURRENTLY SUPPORTED                OTH              0
# ..                      ...                ...            ...
# 70  NOT CURRENTLY SUPPORTED                COM         760951
# 71  NOT CURRENTLY SUPPORTED                IND              0
# 72  NOT CURRENTLY SUPPORTED                COM         743103
# 73  NOT CURRENTLY SUPPORTED                IND              0
# 74  NOT CURRENTLY SUPPORTED                IND              0
# 75  NOT CURRENTLY SUPPORTED                IND              0
# 76  NOT CURRENTLY SUPPORTED                IND              0
# 77  NOT CURRENTLY SUPPORTED                IND              0
# 78  NOT CURRENTLY SUPPORTED                IND              0
# 79  NOT CURRENTLY SUPPORTED                IND              0
# 80  NOT CURRENTLY SUPPORTED                IND              0
# 81  NOT CURRENTLY SUPPORTED                OTH              0
# 82  NOT CURRENTLY SUPPORTED                SCC         790318
# 83  NOT CURRENTLY SUPPORTED                OTH              0
# 84  NOT CURRENTLY SUPPORTED                IND              0
# 85  NOT CURRENTLY SUPPORTED                IND              0
# 86  NOT CURRENTLY SUPPORTED                IND              0
# 87  NOT CURRENTLY SUPPORTED                IND              0
# 88  NOT CURRENTLY SUPPORTED                OTH              0
# 89  NOT CURRENTLY SUPPORTED                OTH              0
# 90  NOT CURRENTLY SUPPORTED                IND              0
# 91  NOT CURRENTLY SUPPORTED                OTH              0
# 92  NOT CURRENTLY SUPPORTED                OTH              0
# 93  NOT CURRENTLY SUPPORTED                COM        1312725
# 94  NOT CURRENTLY SUPPORTED                COM         743365
# 95  NOT CURRENTLY SUPPORTED                OTH              0
# 96  NOT CURRENTLY SUPPORTED                OTH              0
# 97  NOT CURRENTLY SUPPORTED                OTH              0
# 98  NOT CURRENTLY SUPPORTED                IND              0
# 99  NOT CURRENTLY SUPPORTED                OTH              0
#
#           donor_entity_type       donor_committee_id     donor_committee_name  \
# 0   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 1   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 2   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 3   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 4   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 5   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 6   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 7   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 8   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 9   NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 10  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 11  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 12  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 13  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 14  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 15  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 16  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 17  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 18  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 19  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 20  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 21  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 22  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 23  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 24  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 25  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 26  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 27  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 28  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 29  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# ..                      ...                      ...                      ...
# 70  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 71  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 72  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 73  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 74  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 75  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 76  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 77  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 78  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 79  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 80  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 81  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 82  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 83  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 84  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 85  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 86  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 87  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 88  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 89  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 90  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 91  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 92  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 93  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 94  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 95  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 96  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 97  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 98  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 99  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
#
#    donor_committee_type donor_committee_party
# 0                  None                  None
# 1                  None                  None
# 2                  None                  None
# 3                  None                  None
# 4                  None                  None
# 5                  None                  None
# 6                  None                  None
# 7                  None                  None
# 8                  None                  None
# 9                  None                  None
# 10                 None                  None
# 11                 None                  None
# 12                 None                  None
# 13                 None                  None
# 14                 None                  None
# 15                 None                  None
# 16                 None                  None
# 17                 None                  None
# 18                 None                  None
# 19                 None                  None
# 20                 None                  None
# 21                 None                  None
# 22                 None                  None
# 23                 None                  None
# 24                 None                  None
# 25                 None                  None
# 26                 None                  None
# 27                 None                  None
# 28                 None                  None
# 29                 None                  None
# ..                  ...                   ...
# 70                 None                  None
# 71                 None                  None
# 72                 None                  None
# 73                 None                  None
# 74                 None                  None
# 75                 None                  None
# 76                 None                  None
# 77                 None                  None
# 78                 None                  None
# 79                 None                  None
# 80                 None                  None
# 81                 None                  None
# 82                 None                  None
# 83                 None                  None
# 84                 None                  None
# 85                 None                  None
# 86                 None                  None
# 87                 None                  None
# 88                 None                  None
# 89                 None                  None
# 90                 None                  None
# 91                 None                  None
# 92                 None                  None
# 93                 None                  None
# 94                 None                  None
# 95                 None                  None
# 96                 None                  None
# 97                 None                  None
# 98                 None                  None
# 99                 None                  None
#
# [100 rows x 28 columns]

# %%
results.shape
# Out:
# (1502264, 28)

# %%
# List out all the rows in the dataframe
print(list(results.index))
# List out all the columns in the dataframe
print(list(results.columns))
# List out the rows, columns in the dataframe
print(list(results.shape))

# %%
# List out all the unique values in a column
results.recipient_committee_name.unique()
# List out all the unique values by column
for col in results.columns:
    print (col + " : " + str(results[col].unique()))

# %%
# List out all rows using location based indexing
results.iloc[:,2]
# List out all rows using keyword based indexing
results.loc[:, 'election_cycle']

# Filter out rows according to column values
results.loc[(results['donor_state'] == 'CA') & (results['donor_organization'] == 'OTH')]

# %%
results[(results['donor_state'] == 'CA') & (results['donor_organization'] == 'OTH')][['transaction_id','transaction_amount']]

# %%
# Group according to category and summarize
results.groupby('recipient_candidate_name')['transaction_amount'].describe()
# Group according to multiple categories and summarize
results.groupby(['recipient_candidate_name', 'transaction_amount'])['transaction_amount'].count()

# %%
# Find cumulative sum by row
results['transaction_amount'].cumsum()

# %%
results.iloc[2,:]

# %%
len(results.index)

# %%
results.head()

# %%
results['transaction_amount'].sum()

# %%
results.groupby('donor_zip_code').sum().sort_values('transaction_amount', ascending = False)

# %%
topspend = ['95814', '95030', '91506', '94010', '90071']
results[results['donor_zip_code'].isin(topspend)][['donor_city', 'donor_state']]

# results[(results['donor_state'] == 'CA') & (results['donor_organization'] == 'OTH')][['transaction_id','transaction_amount']]
# results.loc[(results['donor_state'] == 'CA') & (results['donor_organization'] == 'OTH')]

# %%
results[(results['election_cycle'] == '2003')].groupby('recipient_candidate_name').sum().sort_values('transaction_amount', ascending = False)

# %%
results[(results['recipient_candidate_name'] == 'POIZNER, STEVE')].groupby('donor_name').sum().sort_values('transaction_amount', ascending = False)

# %%
donorsum = results.groupby('donor_name').sum().sort_values('transaction_amount', ascending = False)
donorsum

# %%
donorsum['cumsum'] = donorsum['transaction_amount'].cumsum()
donorsum['percentile'] = donorsum['cumsum'] / donorsum['transaction_amount'].sum()
donorsum[(donorsum['percentile'] <= .5)].shape
